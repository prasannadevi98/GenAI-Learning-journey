# %% [markdown]
# ### if ,elif,else ###

# %% [markdown]
# syntax
# *  if \< condition>\:
#
# *  elif \< condition>\:
#
# *  else\:

# %%
a =10
if a >100:
    print("a is greater than 100")

else:
    print("python is awesome")
# Out:
# python is awesome

# %%
a=105
if a>100:
    print("a is greater than 100")
    print ("python is awesome ")

else: print (a,"is lesser than 100")


a= 10
if a<100:
    print ("a is lesser than 100")
# Out:
# a is greater than 100
# python is awesome
# a is lesser than 100

# %%
a=100
b=200
if a>100 and b>100:
    print ("both a and b are greater than100")
else: print ("a ,b sum of total")
print ("a is lesser  than b ")
# Out:
# a ,b sum of total
# a is lesser  than b

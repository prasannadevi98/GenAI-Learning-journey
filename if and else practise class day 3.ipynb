# %% [markdown]
# ### if ,elif,else ###

# %% [markdown]
# syntax
# *  if \< condition>\:
#
# *  elif \< condition>\:
#
# *  else\:

# %%
a =10
if a >100:
    print("a is greater than 100")

else:
    print("python is awesome")
# Out:
# python is awesome

# %% [markdown]
# ## ** print the blow pattern *
#
#     #
#    ##
#   ###
#  ####
# #####

# %%
x = 5

for i in range(x, 0, -1):
    print("#" * i)
# Out:
#     #
#    ##
#   ###
#  ####
# #####

# %% [markdown]
# ## ** print blow pattern (2/9/2026)

# %%
x=5
for i in range (1,x+1):
    spaces=" "*(x-i)
    hashes ="#"*i
    print (spaces+hashes)
# Out:
#     #
#    ##
#   ###
#  ####
# #####

# %%
x=5
for i in range(5):
    print( " " * (4-i) + "#" * (i+1))
print()
# Out:
#     #
#    ##
#   ###
#  ####
# #####

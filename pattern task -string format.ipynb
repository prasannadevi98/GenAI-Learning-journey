# %% [markdown]
# ## ** print blow the pattern*
# # enter a number bw 0-9:9
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999

# %%
num = int(input ("enter the number 0,1-9:"))
for i in range(0,num+1):
    print(str(i)*i)
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999

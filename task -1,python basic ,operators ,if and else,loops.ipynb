# %% [markdown]
# ## task -1 ##
# **python basic **

# %%
name ="prasanna"
age ="27" 
city= " chennai  "
professional ="Ai engineer"


print (name,age,city,professional)
# Out:
# prasanna 27  chennai   Ai engineer

# %%
no_1 =input("enter the first number") 
no_2 =input("enter the second number")
no_1=int(no_1)
no_2=int(no_2)
sum=no_1+no_2

print (" total of no_1 ,no_2 is ", sum)
# Out:
#  total of no_1 ,no_2 is  80

# %%
print (no_1,no_2)
# Out:
# 30 50

# %% [markdown]
# ## ** 2nd question Difference **

# %%
no_1=input("enter the first number")
no_2= input ("enter the second number")
no_1 = int(no_1)
no_2= int(no_2)
print( no_1 - no_2)
# Out:
# -20

# %% [markdown]
# ## **product**

# %%
no_1= input ("enter the first number")
no_2 =input ("enter the second number")
no_1 =int(no_1)
no_2 =int(no_2)
print(no_1 * no_2)
# Out:
# 1500

# %% [markdown]
# ## **quotient** ##

# %%
no_1= input ("enter the first number")
no_2 =input ("enter the second number")
no_1 =int(no_1)
no_2 =int(no_2)
print(no_1 / no_2)
# Out:
# 0.6

# %% [markdown]
# ## **3rd question **

# %%
# Write a program to input the length and breadth of a rectangle and calculate its area and perimeter #
 
length =input ("enter the length value ")
breath = input ("enter the breath value ")
length =int(length)
breath =int(breath)
print( length ,breath )

lenth =10
breath = 20
area = length * breath
print(area) 

perimeter =2*(length +breath)
print (perimeter)
# Out:
# 10 20
# 200
# 60

# %% [markdown]
# ## ** 4th question*

# %%
# Write a program to convert temperature from Celsius to Fahrenheit. 


celsius =input ("enter the temperatur value")
print ("enter the temperature value")
print (celsius)
celsius = float(celsius)

fahrenheit =(celsius*9/5)+32
print (fahrenheit)
# Out:
# enter the temperature value
# 40
# 104.0

# %% [markdown]
# ## **student mark **

# %%
#  Write a program to input a student's name and marks in three subjects and display the total and average

student_name = "prasanna"
marks = ["maths =85""science=90""english=95"]
total_marks =(85+90+95)
print(total_marks)
# Out:
# 270
